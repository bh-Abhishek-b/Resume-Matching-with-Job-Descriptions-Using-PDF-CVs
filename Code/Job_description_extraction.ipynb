# %%
import pandas as pd

# %% [markdown]
# # Reading the dataset from Hugging Face

# %%
df=pd.read_csv('/home/mav_27/Internship Assignment/Data/Hugging/training_data.csv')

# %%
df.head()
# Out:
#   company_name                                    job_description  \
# 0       Google  minimum qualifications\nbachelors degree or eq...
# 1        Apple  description\nas an asc you will be highly infl...
# 2      Netflix  its an amazing time to be joining netflix as w...
# 3  Robert Half  description\n\nweb designers looking to expand...
# 4    TrackFive  at trackfive weve got big goals were on a miss...
#
#                               position_title  description_length  \
# 0                           Sales Specialist                2727
# 1                 Apple Solutions Consultant                 828
# 2  Licensing Coordinator - Consumer Products                3205
# 3                               Web Designer                2489
# 4                              Web Developer                3167
#
#                                       model_response
# 0   {\n  "Core Responsibilities": "Responsible fo...
# 1   {\n  "Core Responsibilities": "as an asc you ...
# ...

# %%
df.head(10)
# Out:
#                               company_name  \
# 0                                   Google
# 1                                    Apple
# 2                                  Netflix
# 3                              Robert Half
# 4                                TrackFive
# 5                                DesignUps
# 6                          Equisolve, Inc.
# 7                  Zander Insurance Agency
# 8                                     Tuff
# 9  General Dynamics Information Technology
#
#                                      job_description  \
# 0  minimum qualifications\nbachelors degree or eq...
# 1  description\nas an asc you will be highly infl...
# 2  its an amazing time to be joining netflix as w...
# 3  description\n\nweb designers looking to expand...
# 4  at trackfive weve got big goals were on a miss...
# 5  designups is a nashville based design and inte...
# 6  about the position\n\nthe web designer is resp...
# 7  job description\n\nzander insurance group is o...
# ...

# %% [markdown]
# # Checking the Job Descriptions

# %%
df['job_description'][1].split('\n')
# Out:
# ['description',
#  'as an asc you will be highly influential in growing mind and market share of apple products while building longterm relationships with those who share your passion ',
#  'customer experiences are driven through you and your partner team growing in an ever changing and challenging environment you strive for perfection whether its maintaining visual merchandising or helping to grow and develop your partner team',
#  '',
#  'qualifications',
#  'a passion to help people understand how apple products can enrich their livesexcellent communication skills allowing you to be as comfortable in front of a small group as you are speaking with individuals years preferred working in a dynamic sales andor results driven environment as well as proven success developing customer loyaltyability to encourage a partner team and grow apple business']

# %% [markdown]
# # Sampling the dataset for random Job Descriptions for Analysis

# %%
sample_df=df.sample(n=15,random_state=74)

# %%
sample_df.drop(['description_length','model_response'],inplace=True,axis=1)

# %%
sample_df
# Out:
#                      company_name  \
# 687                    McDonald's
# 584     Jewish Community Services
# 760         RB American Group LLC
# 71         Berryman Chemical Inc.
# 313                        Pragma
# 532     Johnson Creek Development
# 335  University Hospitals Careers
# 754                    Altice USA
# 698                        Paligo
# 112                           PwC
# 418     Holman Frenia Allison, PC
# 666         A Media.Monks Company
# 76            New Fortress Energy
# 45                AVI Foodsystems
# 376                        Mizuho
#
#                                        job_description  \
# 687  this job posting is for a position in a restau...
# 584  jewish community services jcs is a comprehensi...
# 760  in a world full of quick service options arbys...
# 71   position supply chain analyst\nreports to seni...
# 313  overview\n\nwere excited to be looking for a g...
# 532  full job description \n\ncommercial constructi...
# ...

# %%
sample_df.to_csv('/home/mav_27/Internship Assignment/sample_df.csv')
